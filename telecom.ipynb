# %%
import pandas as pd
import numpy as np

# %%
telecom = pd.read_csv('Invoice_20201220.csv', sep='|')
telecom
# Out:
#                 SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD  \
# 0      12345_GEO (0001BB)     1300082549  01/01/2018  31/01/2018      2 447
# 1      12345_GEO (0001BB)     1300082549  01/02/2018  28/02/2018      2 211
# 2      12345_GEO (0001BB)     1300082549  01/03/2018  31/03/2018      2 450
# 3      12345_GEO (0001BB)     1300082549  01/04/2018  30/04/2018      2 431
# 4      12345_GEO (0001BB)     1300082549  01/05/2018  31/05/2018      2 574
# ...                   ...            ...         ...         ...        ...
# 51427  19767_GEO (0632KO)  FV1/055100030  30/08/2019  31/12/2019      3 028
# 51428  19767_GEO (0632KO)      055100058  01/01/2020  31/03/2020      2 163
# 51429  19767_GEO (0632KO)      055100113  01/04/2020  30/06/2020      2 160
# 51430  19767_GEO (0632KO)      055100168  01/07/2020  30/09/2020      2 230
# 51431  19883_GEO (1203KO)     7220278453  27/09/2019  31/12/2019      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# ...

# %%
telecom[['SITE_NAME','SITE2']] = telecom['SITE_NAME'].str.split('(',expand=True)

# %%
telecom
# Out:
#         SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD  \
# 0      12345_GEO      1300082549  01/01/2018  31/01/2018      2 447
# 1      12345_GEO      1300082549  01/02/2018  28/02/2018      2 211
# 2      12345_GEO      1300082549  01/03/2018  31/03/2018      2 450
# 3      12345_GEO      1300082549  01/04/2018  30/04/2018      2 431
# 4      12345_GEO      1300082549  01/05/2018  31/05/2018      2 574
# ...           ...            ...         ...         ...        ...
# 51427  19767_GEO   FV1/055100030  30/08/2019  31/12/2019      3 028
# 51428  19767_GEO       055100058  01/01/2020  31/03/2020      2 163
# 51429  19767_GEO       055100113  01/04/2020  30/06/2020      2 160
# 51430  19767_GEO       055100168  01/07/2020  30/09/2020      2 230
# 51431  19883_GEO      7220278453  27/09/2019  31/12/2019      4 745
#
#       PERIOD_EUR    SITE2
# 0         316,46  0001BB)
# 1         286,82  0001BB)
# 2         317,32  0001BB)
# 3         315,00  0001BB)
# ...

# %%
#cette partie sert à faire quelques arrangements sur les colonnes : modifier les noms et l'ordre
telecom = telecom[['SITE_NAME', 'SITE2', 'INVOICE_NAME', 'BEGIN', 'END', 'KWH_PERIOD', 'PERIOD_EUR']]
telecom.rename(columns = {'SITE_NAME':'SITE_ID', 'SITE2':'ANTENNA_ID'}, inplace = True)
cols = list(telecom.columns.values) #pour vérifier les changements sur les colonnes
cols
# Out:
# ['SITE_ID',
#  'ANTENNA_ID',
#  'INVOICE_NAME',
#  'BEGIN',
#  'END',
#  'KWH_PERIOD',
#  'PERIOD_EUR']

# %%
def clean_string(string):
        string = string[:-1]
        return string

    
telecom['ANTENNA_ID'] = telecom['ANTENNA_ID'].apply(clean_string)
telecom
# Out:
#           SITE_ID ANTENNA_ID   INVOICE_NAME       BEGIN         END  \
# 0      12345_GEO      0001BB     1300082549  01/01/2018  31/01/2018
# 1      12345_GEO      0001BB     1300082549  01/02/2018  28/02/2018
# 2      12345_GEO      0001BB     1300082549  01/03/2018  31/03/2018
# 3      12345_GEO      0001BB     1300082549  01/04/2018  30/04/2018
# 4      12345_GEO      0001BB     1300082549  01/05/2018  31/05/2018
# ...           ...        ...            ...         ...         ...
# 51427  19767_GEO      0632KO  FV1/055100030  30/08/2019  31/12/2019
# 51428  19767_GEO      0632KO      055100058  01/01/2020  31/03/2020
# 51429  19767_GEO      0632KO      055100113  01/04/2020  30/06/2020
# 51430  19767_GEO      0632KO      055100168  01/07/2020  30/09/2020
# 51431  19883_GEO      1203KO     7220278453  27/09/2019  31/12/2019
#
#       KWH_PERIOD PERIOD_EUR
# 0          2 447     316,46
# 1          2 211     286,82
# 2          2 450     317,32
# 3          2 431     315,00
# ...

# %%
telecom[telecom['ANTENNA_ID'].map(len) < 7]

#def check (code):
    bool(code) and code[-1].isdigit()

#check(telecom['ANTENNA_ID'])
# Out:
#   File "C:\Users\pc\AppData\Local\Temp/ipykernel_9108/934640563.py", line 4
#     bool(code) and code[-1].isdigit()
#     ^
# IndentationError: unexpected indent

# %%
telecom = telecom.drop(columns = ['INVOICE_NAME'])
cols
# Out:
# ['SITE_ID',
#  'ANTENNA_ID',
#  'INVOICE_NAME',
#  'BEGIN',
#  'END',
#  'KWH_PERIOD',
#  'PERIOD_EUR']

# %%
telecom.insert(5, "Nombre_jours", " ")
cols
telecom
# Out:
#           SITE_ID ANTENNA_ID       BEGIN         END KWH_PERIOD Nombre_jours  \
# 0      12345_GEO      0001BB  01/01/2018  31/01/2018      2 447
# 1      12345_GEO      0001BB  01/02/2018  28/02/2018      2 211
# 2      12345_GEO      0001BB  01/03/2018  31/03/2018      2 450
# 3      12345_GEO      0001BB  01/04/2018  30/04/2018      2 431
# 4      12345_GEO      0001BB  01/05/2018  31/05/2018      2 574
# ...           ...        ...         ...         ...        ...          ...
# 51427  19767_GEO      0632KO  30/08/2019  31/12/2019      3 028
# 51428  19767_GEO      0632KO  01/01/2020  31/03/2020      2 163
# 51429  19767_GEO      0632KO  01/04/2020  30/06/2020      2 160
# 51430  19767_GEO      0632KO  01/07/2020  30/09/2020      2 230
# 51431  19883_GEO      1203KO  27/09/2019  31/12/2019      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# ...

# %%
telecom['BEGIN'] = telecom['BEGIN'].str.replace("/",", ")
telecom['END'] = telecom['END'].str.replace("/",", ")
def jours(debut,fin):
    import datetime
    born = datetime.date(debut)
    today = datetime.date(fin)
    diff = today - born
    print(diff.total_seconds())
jours(telecom['BEGIN'], telecom['END'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9108/2738474164.py in <module>
#       7     diff = today - born
#       8     print(diff.total_seconds())
# ----> 9 jours(telecom['BEGIN'], telecom['END'])
#
# ~\AppData\Local\Temp/ipykernel_9108/2738474164.py in jours(debut, fin)
#       3 def jours(debut,fin):
#       4     import datetime
# ----> 5     born = datetime.date(debut)
#       6     today = datetime.date(fin)
#       7     diff = today - born
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
def difference_dates(debut, fin):
    from datetime import datetime
    x = datetime.now(debut)
    y = datetime.now(fin)
    delta = y - x
    return delta 
telecom['daysPeriod'] = telecom['BEGIN'],telecom['END'].apply(difference_dates)
telecom
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9108/1080910643.py in <module>
#       5     delta = y - x
#       6     return delta
# ----> 7 telecom['daysPeriod'] = telecom['BEGIN'],telecom['END'].apply(difference_dates)
#       8 telecom
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
# Out:
#   File "C:\Users\pc\AppData\Local\Temp/ipykernel_9108/1754425168.py", line 5
#     telecom.drop(telecom[telecom.ANTENNA_ID < 50].index, inplace=True
#                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
def check (code):
    bool(code) and code[-1].isdigit()

check(telecom['ANTENNA_ID'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9108/3485167539.py in <module>
#       2     bool(code) and code[-1].isdigit()
#       3
# ----> 4 check(telecom['ANTENNA_ID'])
#
# ~\AppData\Local\Temp/ipykernel_9108/3485167539.py in check(code)
#       1 def check (code):
# ----> 2     bool(code) and code[-1].isdigit()
#       3
#       4 check(telecom['ANTENNA_ID'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
telecom.to_csv('datacleaner.csv' , index=False)
